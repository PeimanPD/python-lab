# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
print("Environment ready!")
# Out:
# Environment ready!

# %%
import pandas as pd
import matplotlib.pyplot as plt

print("Environment ready!")
# Tiny sanity plot
x = [300,400,500,600,700]
y = [2300,2000,1700,1400,1200]
plt.scatter(x, y)
plt.gca().invert_yaxis()
plt.xlabel("F1 (Hz)")
plt.ylabel("F2 (Hz)")
plt.title("Sample Vowel Space")
plt.show()
# Out:
# Environment ready!
